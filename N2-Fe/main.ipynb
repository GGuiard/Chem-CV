# %%
import os
os.chdir("..")

from utils.postprocessing import postprocessing

os.chdir("N2-Fe")

# %%
cv = {
    "d": {
        "label": r"$d_{N-N}$  [Å]",
        "bounds": (1.0, 2.0),
    },
    "c": {
        "label": "Coordination",
        "bounds": (1.0, 12.0),
    },
}

postprocessing(
    # --- CV selection ---
    cv=cv,
    cv_1d=["d", "c"],
    cv_2d=[("d", "c")],

    # --- Display limits ---
    fes_max_1d=1.0,
    fes_max_2d=1.0,
    error_max_2d=0.01,

    # --- General options ---
    directory="OPES_2",
    show=False,
)

# %%
cv = {
    "d": {
        "label": r"$d_{N-N}$  [Å]",
        "bounds": (1.0, 2.0),
    },
    "c": {
        "label": "Coordination",
        "bounds": (1.0, 12.0),
    },
    "q.node-0": {
        "label": r"$q_N\ [e]$",
        "bounds": (0.0, 1.5),
    },
}

postprocessing(
    # --- CV selection ---
    cv=cv,
    cv_1d=["d", "c", "q.node-0"],
    cv_2d=[("d", "c"), ("d", "q.node-0")],

    # --- Display limits ---
    fes_max_1d=1.0,
    fes_max_2d=1.0,
    error_max_2d=0.01,

    # --- General options ---
    directory="OPES_Q2",
    show=False,
)
